# %%
# !pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.16.0-cp311-cp311-win_amd64.whl.metadata (10.0 kB)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in C:\Users\STUDENT\AppData\Local\ESRI\conda\envs\inkomoko-backend\Lib\site-packages (from pymongo[srv]) (2.8.0)
# Downloading pymongo-4.16.0-cp311-cp311-win_amd64.whl (855 kB)
#    ---------------------------------------- 0.0/855.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/855.8 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/855.8 kB ? eta -:--:--
#    ------------------------------------ --- 786.4/855.8 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 855.8/855.8 kB 2.7 MB/s  0:00:00
# Installing collected packages: pymongo
# Successfully installed pymongo-4.16.0
# WARNING: pymongo 4.16.0 does not provide the extra 'srv'

# %%
import pymongo

# Paste your updated string here
uri = "mongodb+srv://Inkomoko:ymosyLynkAPr86EI@cluster0.2wssn.mongodb.net/?appName=Cluster0"

client = pymongo.MongoClient(uri)

# Test the connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# !pip install python-jose
